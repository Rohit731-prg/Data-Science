# %%
import pandas as pd

data = pd.read_csv("Data.csv")
data
# Out:
#   Employee ID Department  Years Experience  Monthly Sales ($)  \
# 0        E101      Sales                 2              14500
# 1        E102  Marketing                 5              22100
# 2        E103      Sales                 1               9800
# 3        E104    Support                 4              12300
# 4        E105  Marketing                 3              18600
# 5        E106      Sales                 8              31000
# 6        E107    Support                 2              11200
# 7        E108      Sales                 6              26400
# 8        E109  Marketing                 1               8900
# 9        E110    Support                 7              15800
#
#    Customer Rating (1-5)
# 0                    4.2
# 1                    4.8
# 2                    3.9
# 3                    4.5
# 4                    4.1
# 5                    4.9
# 6                    3.7
# 7                    4.6
# 8                    4.0
# 9                    4.3

# %%
import matplotlib.pyplot as plt

new_data_set = data[['Monthly Sales ($)', 'Years Experience']]
new_data_set.head(1)
# Out:
#    Years Experience  Monthly Sales ($)
# 0                 2              14500

# %%
plt.hist(new_data_set, bins=10)
plt.xlabel("Years Experience")
plt.ylabel("Monthly Sales ($)")
plt.title("Histogramic chart")
plt.show()
