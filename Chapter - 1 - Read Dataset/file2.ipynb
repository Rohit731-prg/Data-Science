# %%
import pandas as pd
data = pd.read_csv("data.csv")

# %%
data.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='str')

# %%
data['Data_value']
# Out:
# 0       1116.386
# 1       1070.874
# 2       1054.408
# 3       1010.665
# 4       1233.700
#           ...
# 9550     699.681
# 9551     587.843
# 9552     658.866
# 9553     734.757
# 9554     884.011
# Name: Data_value, Length: 9555, dtype: float64

# %%
data['Data_value'].max()
# Out:
# np.float64(43002.425)

# %%
data[data['Data_value'] == data['Data_value'].max()]
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 2318    BDCQ.SF1FF1CA  2025.12   43002.425        NaN      F  Dollars
# 2438     BDCQ.SF1FFCA  2025.12   43002.425        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 2318          6  Business Data Collection - BDC
# 2438          6  Business Data Collection - BDC
#
#                                                 Group  \
# 2318  Industry by financial variable (NZSIOC Level 2)
# 2438  Industry by financial variable (NZSIOC Level 1)
#
#                 Series_title_1   Series_title_2  Series_title_3  \
# 2318  Sales (operating income)  Wholesale Trade  Current prices
# 2438  Sales (operating income)  Wholesale Trade         Current
#
#      Series_title_4  Series_title_5
# 2318     Unadjusted             NaN
# 2438     Unadjusted             NaN

# %%
data[data['Data_value'] == data['Data_value'].max()]['Subject']
# Out:
# 2318    Business Data Collection - BDC
# 2438    Business Data Collection - BDC
# Name: Subject, dtype: str
